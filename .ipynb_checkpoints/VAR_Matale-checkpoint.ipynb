# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.varmax import VARMAX
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import grangercausalitytests, adfuller
from sklearn.impute import SimpleImputer # import simple imputer
from math import sqrt
from sklearn.metrics import mean_squared_error,mean_absolute_error,mean_absolute_percentage_error,r2_score

# %%
filepath = '../Data/final/Matale_demand.csv'
data = pd.read_csv(filepath, index_col="Month",parse_dates=["Month"])
print(data.shape) 
data.head()
# Out:
# (84, 7)
#                Demand  Temp_Avg  Temp_Max  Temp_Min  Rainfall_Avg  \
# Month
# 2015-01-01  12.837910      24.1      29.3      18.9           5.3
# 2015-02-01  13.137065      24.2      29.5      18.9          97.0
# 2015-03-01  13.030748      25.8      32.1      19.5          57.6
# 2015-04-01  14.171026      26.0      31.0      21.0         157.3
# 2015-05-01  13.828775      26.0      30.7      21.2         141.5
#
#             HumidityDay  HumidityNight
# Month
# 2015-01-01         68.0           92.0
# 2015-02-01         71.0           92.0
# 2015-03-01         65.0           93.0
# 2015-04-01         77.0           95.0
# 2015-05-01         75.0           95.0

# %%
data.describe(include='all')
# Out:
#           Demand   Temp_Avg   Temp_Max   Temp_Min  Rainfall_Avg  HumidityDay  \
# count  84.000000  84.000000  84.000000  84.000000     84.000000    83.000000
# mean   17.119833  25.398810  29.889286  20.913095    137.957143    73.638554
# std     2.108605   0.834713   1.356112   1.093109    118.140802     5.730914
# min    12.837910  22.800000  28.000000  17.200000      3.600000    58.000000
# 25%    15.690414  24.900000  28.900000  20.300000     53.875000    69.000000
# 50%    17.327604  25.400000  29.550000  21.200000    106.650000    75.000000
# 75%    18.398862  25.800000  30.550000  21.625000    165.275000    78.000000
# max    26.738655  27.500000  33.600000  22.800000    509.200000    83.000000
#
#        HumidityNight
# count      83.000000
# mean       92.807229
# std         2.534916
# min        86.000000
# 25%        91.000000
# 50%        93.000000
# 75%        95.000000
# max        97.000000

# %%
data.isnull().sum() #return true/ false. If ture , its a missing place. If false, it contains a values.
# Out:
# Demand           0
# Temp_Avg         0
# Temp_Max         0
# Temp_Min         0
# Rainfall_Avg     0
# HumidityDay      1
# HumidityNight    1
# dtype: int64

# %%
sample_data= data.copy()
sample_data.isnull().sum()
# Out:
# Demand           0
# Temp_Avg         0
# Temp_Max         0
# Temp_Min         0
# Rainfall_Avg     0
# HumidityDay      1
# HumidityNight    1
# dtype: int64

# %%
imputer = SimpleImputer(missing_values=np.NaN, strategy='mean') 
# sample_data.Rainfall_Avg = imputer.fit_transform(sample_data['Rainfall_Avg'].values.reshape(-1,1))[:,0]
sample_data.HumidityDay = imputer.fit_transform(sample_data['HumidityDay'].values.reshape(-1,1))[:,0]
sample_data.HumidityNight = imputer.fit_transform(sample_data['HumidityNight'].values.reshape(-1,1))[:,0]
# sample_data= sample_data.drop(columns='HumidityNight')
sample_data.isnull().sum()
# Out:
# Demand           0
# Temp_Avg         0
# Temp_Max         0
# Temp_Min         0
# Rainfall_Avg     0
# HumidityDay      0
# HumidityNight    0
# dtype: int64

# %%
plt.boxplot(sample_data["Temp_Avg"])  #finding outliers
plt.show()

# %%
plt.boxplot(sample_data["Temp_Min"])  #finding outliers
plt.show()

# %%
plt.boxplot(sample_data["Temp_Max"])  #finding outliers
plt.show()

# %%
plt.boxplot(sample_data["Rainfall_Avg"])  #finding outliers
plt.show()

# %%
plt.boxplot(sample_data["HumidityDay"])  #finding outliers
plt.show()

# %%
plt.boxplot(sample_data["HumidityNight"])  #finding outliers
plt.show()

# %%
color_list=["blue","green","red","olive","orange","purple","brown"]

fig, axes = plt.subplots(nrows=7, ncols=1, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data = sample_data[sample_data.columns[i]]
    ax.plot(data, color=color_list[i%(len(color_list))], linewidth=1)
    
    ax.set_title(sample_data.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %%
#check weather data stationary or not(augmented dickey-fuller test)

ad_fuller_result_1 = adfuller(sample_data['Demand'])#.diff()[1:])

print('Demand')
print(f'ADF Statistic: {ad_fuller_result_1[0]}')
print(f'p-value: {ad_fuller_result_1[1]}')

print('\n---------------------\n')

ad_fuller_result_2 = adfuller(sample_data['Temp_Avg'])#.diff()[1:])

print('Average Temperature')
print(f'ADF Statistic: {ad_fuller_result_2[0]}')
print(f'p-value: {ad_fuller_result_2[1]}')

print('\n---------------------\n')

ad_fuller_result_2 = adfuller(sample_data['Temp_Max'])#.diff()[1:])

print('Maximum Temperature')
print(f'ADF Statistic: {ad_fuller_result_2[0]}')
print(f'p-value: {ad_fuller_result_2[1]}')

print('\n---------------------\n')

ad_fuller_result_2 = adfuller(sample_data['Temp_Min'])#.diff()[1:])

print('Minimum Temperature')
print(f'ADF Statistic: {ad_fuller_result_2[0]}')
print(f'p-value: {ad_fuller_result_2[1]}')

print('\n---------------------\n')

ad_fuller_result_2 = adfuller(sample_data['Rainfall_Avg'])#.diff()[1:])

print('Average Rainfall')
print(f'ADF Statistic: {ad_fuller_result_2[0]}')
print(f'p-value: {ad_fuller_result_2[1]}')

print('\n---------------------\n')

ad_fuller_result_2 = adfuller(sample_data['HumidityDay'])#.diff()[1:])

print('Humidity Day')
print(f'ADF Statistic: {ad_fuller_result_2[0]}')
print(f'p-value: {ad_fuller_result_2[1]}')

print('\n---------------------\n')

# ad_fuller_result_2 = adfuller(sample_data['HumidityNight'])#.diff()[1:])

# print('Humidity Night')
# print(f'ADF Statistic: {ad_fuller_result_2[0]}')
# print(f'p-value: {ad_fuller_result_2[1]}')

# p value shold be , p <0.05
# Out:
# Demand
# ADF Statistic: -2.1519140541191666
# p-value: 0.22415815714128484
#
# ---------------------
#
# Average Temperature
# ADF Statistic: -2.105728671422644
# p-value: 0.24221732221915016
#
# ---------------------
#
# Maximum Temperature
# ADF Statistic: -1.6295432657432785
# p-value: 0.4677297953139682
#
# ---------------------
#
# Minimum Temperature
# ADF Statistic: -1.7617691051260413
# p-value: 0.3996005563015002
#
# ---------------------
#
# Average Rainfall
# ADF Statistic: -2.593806616340718
# p-value: 0.09428408209339778
#
# ---------------------
#
# Humidity Day
# ADF Statistic: -1.5316315215051342
# p-value: 0.5178097122726508
#
# ---------------------

# %%
# do first order differencing

ad_fuller_result_1= adfuller(sample_data['Demand'].diff()[1:])

print('Demand')
print(f'ADF Statistic: {ad_fuller_result_1[0]}')
print(f'p-value: {ad_fuller_result_1[1]}')

print('\n---------------------\n')

ad_fuller_result_2 = adfuller(sample_data['Temp_Avg'].diff()[1:])

print('Average Temperature')
print(f'ADF Statistic: {ad_fuller_result_2[0]}')
print(f'p-value: {ad_fuller_result_2[1]}')

print('\n---------------------\n')

ad_fuller_result_2 = adfuller(sample_data['Temp_Max'].diff()[1:])

print('Maximum Temperature')
print(f'ADF Statistic: {ad_fuller_result_2[0]}')
print(f'p-value: {ad_fuller_result_2[1]}')

print('\n---------------------\n')

ad_fuller_result_2 = adfuller(sample_data['Temp_Min'].diff()[1:])

print('Minimum Temperature')
print(f'ADF Statistic: {ad_fuller_result_2[0]}')
print(f'p-value: {ad_fuller_result_2[1]}')

print('\n---------------------\n')

ad_fuller_result_2 = adfuller(sample_data['Rainfall_Avg'].diff()[1:])

print('Average Rainfall')
print(f'ADF Statistic: {ad_fuller_result_2[0]}')
print(f'p-value: {ad_fuller_result_2[1]}')

print('\n---------------------\n')

ad_fuller_result_2 = adfuller(sample_data['HumidityDay'].diff()[1:])

print('Humidity Day')
print(f'ADF Statistic: {ad_fuller_result_2[0]}')
print(f'p-value: {ad_fuller_result_2[1]}')

print('\n---------------------\n')

ad_fuller_result_2 = adfuller(sample_data['HumidityNight'].diff()[1:])

print('Humidity Night')
print(f'ADF Statistic: {ad_fuller_result_2[0]}')
print(f'p-value: {ad_fuller_result_2[1]}')

# %%
sample_data.head(5)
# Out:
#                Demand  Temp_Avg  Temp_Max  Temp_Min  Rainfall_Avg  HumidityDay
# Month
# 2015-01-01  21.019726      26.6      32.1      21.1           5.9         62.0
# 2015-02-01  20.906431      27.1      32.8      21.4          33.9         63.0
# 2015-03-01  20.591265      28.5      34.5      22.5         207.2         61.0
# 2015-04-01  21.613543      28.2      33.3      23.2         367.5         73.0
# 2015-05-01  21.594135      28.7      32.8      24.6          69.7         75.0

# %%
# make first-order differencing 
df_transformed = sample_data.diff().dropna()
df = sample_data.iloc[1:]
print(df.shape)
df_transformed.shape
df_transformed.head()
# Out:
# (83, 7)
#               Demand  Temp_Avg  Temp_Max  Temp_Min  Rainfall_Avg  HumidityDay  \
# Month
# 2015-02-01  0.299155       0.1       0.2       0.0          91.7          3.0
# 2015-03-01 -0.106317       1.6       2.6       0.6         -39.4         -6.0
# 2015-04-01  1.140278       0.2      -1.1       1.5          99.7         12.0
# 2015-05-01 -0.342251       0.0      -0.3       0.2         -15.8         -2.0
# 2015-06-01  0.915296      -0.3      -1.1       0.6         -35.4         -1.0
#
#             HumidityNight
# Month
# 2015-02-01            0.0
# 2015-03-01            1.0
# 2015-04-01            2.0
# 2015-05-01            0.0
# 2015-06-01           -3.0

# %%
#Test the Granger Causality

max_lags=6
y='Demand'

for i in range(len(df_transformed.columns)-1):
    results=grangercausalitytests(df_transformed[[y,df_transformed.columns[i+1]]],max_lags,verbose=False)
    p_values=[round(results[i+1][0]['ssr_ftest'][1],4)for i in range(max_lags)]
    print('column-{} :P_values - {}'.format(df_transformed.columns[i+1],p_values))
# Out:
# column-Temp_Avg :P_values - [0.1113, 0.0411, 0.099, 0.0722, 0.0738, 0.0197]
# column-Temp_Max :P_values - [0.1705, 0.4026, 0.8134, 0.8173, 0.9179, 0.8158]
# column-Temp_Min :P_values - [0.5795, 0.0299, 0.0284, 0.0242, 0.0221, 0.0079]
# column-Rainfall_Avg :P_values - [0.6015, 0.9325, 0.8587, 0.9568, 0.4205, 0.4695]
# column-HumidityDay :P_values - [0.7064, 0.9186, 0.6929, 0.748, 0.8061, 0.8866]
# column-HumidityNight :P_values - [0.4672, 0.3277, 0.2984, 0.368, 0.3607, 0.1779]

# %%
df_input=sample_data[['Demand','Temp_Avg']]

# %%
df_input
# Out:
#                Demand  Temp_Avg
# Month
# 2015-01-01  12.837910      24.1
# 2015-02-01  13.137065      24.2
# 2015-03-01  13.030748      25.8
# 2015-04-01  14.171026      26.0
# 2015-05-01  13.828775      26.0
# ...               ...       ...
# 2021-08-01  19.855330      25.2
# 2021-09-01  18.928359      25.3
# 2021-10-01  19.511670      25.4
# 2021-11-01  20.258340      24.8
# 2021-12-01  19.257245      25.1
#
# [84 rows x 2 columns]

# %%
df_train=df_input[:-12]
df_test=df_input[-12:]

# %%
df_train.shape
# Out:
# (72, 2)

# %%
df_test.shape
# Out:
# (12, 2)

# %%
model = VAR(df_train.diff()[1:])
# Out:
# C:\Users\Shani\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
sorted_order=model.select_order(maxlags=16)
print(sorted_order.summary())
# Out:
#  VAR Order Selection (* highlights the minimums)
# ==================================================
#        AIC         BIC         FPE         HQIC
# --------------------------------------------------
# 0        1.111       1.184       3.039       1.140
# 1        1.030       1.249       2.802       1.115
# 2       0.8049       1.170       2.239      0.9460
# 3       0.6944       1.205       2.008      0.8919
# 4       0.4919      1.149*       1.645     0.7459*
# 5       0.5151       1.318       1.692      0.8256
# 6       0.4935       1.442       1.668      0.8605
# 7       0.5463       1.641       1.776      0.9697
# 8       0.6046       1.846       1.909       1.084
# 9       0.2198       1.607      1.322*      0.7561
# 10      0.2009       1.734       1.326      0.7937
# 11      0.2548       1.934       1.439      0.9041
# 12      0.1760       2.001       1.376      0.8816
# 13      0.1679       2.139       1.424      0.9300
# 14      0.1175       2.234       1.425      0.9361
# 15      0.1147       2.378       1.511      0.9898
# 16     0.1001*       2.509       1.604       1.032
# --------------------------------------------------

# %%
var_model = VARMAX(df_train, order=(16,0),enforce_stationarity= True)
fitted_model = var_model.fit(disp=False)
print(fitted_model.summary())
# Out:
# C:\Users\Shani\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\Shani\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:374: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\Shani\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                              Statespace Model Results
# ==================================================================================
# Dep. Variable:     ['Demand', 'Temp_Avg']   No. Observations:                   72
# Model:                            VAR(16)   Log Likelihood                -196.695
#                               + intercept   AIC                            531.390
# Date:                    Mon, 27 Feb 2023   BIC                            688.480
# Time:                            20:50:52   HQIC                           593.928
# Sample:                        01-01-2015
#                              - 12-01-2020
# Covariance Type:                      opg
# ===================================================================================
# Ljung-Box (L1) (Q):            3.14, 14.97   Jarque-Bera (JB):          34.78, 8.60
# Prob(Q):                        0.08, 0.00   Prob(JB):                   0.00, 0.01
# Heteroskedasticity (H):         2.67, 0.57   Skew:                     -0.57, -0.21
# Prob(H) (two-sided):            0.02, 0.17   Kurtosis:                   6.21, 4.64
#                           Results for equation Demand
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# intercept       16.8127    429.231      0.039      0.969    -824.464     858.090
# L1.Demand       -0.1060      1.452     -0.073      0.942      -2.952       2.740
# L1.Temp_Avg      0.1416      5.736      0.025      0.980     -11.100      11.384
# L2.Demand       -0.1599      1.747     -0.091      0.927      -3.585       3.265
# L2.Temp_Avg      0.2629      5.543      0.047      0.962     -10.601      11.127
# L3.Demand       -0.0362      1.863     -0.019      0.984      -3.687       3.614
# L3.Temp_Avg      0.0605      5.167      0.012      0.991     -10.066      10.187
# L4.Demand        0.0251      1.078      0.023      0.981      -2.087       2.137
# L4.Temp_Avg      0.1393      4.835      0.029      0.977      -9.337       9.616
# L5.Demand        0.0294      3.013      0.010      0.992      -5.876       5.935
# L5.Temp_Avg      0.0964      7.967      0.012      0.990     -15.519      15.712
# L6.Demand        0.0482      2.562      0.019      0.985      -4.973       5.069
# L6.Temp_Avg      0.1287      6.119      0.021      0.983     -11.864      12.121
# L7.Demand        0.1274      3.504      0.036      0.971      -6.741       6.995
# L7.Temp_Avg     -0.1174      7.693     -0.015      0.988     -15.196      14.961
# L8.Demand        0.1002      3.367      0.030      0.976      -6.499       6.699
# L8.Temp_Avg     -0.2044      8.957     -0.023      0.982     -17.759      17.350
# L9.Demand        0.1555      4.651      0.033      0.973      -8.960       9.271
# L9.Temp_Avg     -0.1455      7.662     -0.019      0.985     -15.162      14.871
# L10.Demand       0.1418      3.288      0.043      0.966      -6.303       6.587
# L10.Temp_Avg    -0.1983      5.561     -0.036      0.972     -11.097      10.700
# L11.Demand       0.1539      4.117      0.037      0.970      -7.916       8.224
# L11.Temp_Avg    -0.1842     13.817     -0.013      0.989     -27.265      26.897
# L12.Demand       0.1402      3.495      0.040      0.968      -6.710       6.990
# L12.Temp_Avg    -0.1268      9.109     -0.014      0.989     -17.981      17.727
# L13.Demand       0.1250      3.186      0.039      0.969      -6.119       6.369
# L13.Temp_Avg    -0.0332      5.292     -0.006      0.995     -10.405      10.338
# L14.Demand       0.0752      2.464      0.031      0.976      -4.754       4.904
# L14.Temp_Avg    -0.0030      8.076     -0.000      1.000     -15.831      15.825
# L15.Demand       0.0709      6.087      0.012      0.991     -11.859      12.001
# L15.Temp_Avg    -0.1395      4.910     -0.028      0.977      -9.763       9.484
# L16.Demand       0.0540      3.021      0.018      0.986      -5.868       5.976
# L16.Temp_Avg    -0.3033      3.670     -0.083      0.934      -7.497       6.891
#                          Results for equation Temp_Avg
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# intercept       25.3963    151.470      0.168      0.867    -271.479     322.272
# L1.Demand       -0.0175      0.384     -0.046      0.964      -0.770       0.735
# L1.Temp_Avg      0.1518      1.287      0.118      0.906      -2.370       2.674
# L2.Demand       -0.0223      0.699     -0.032      0.975      -1.393       1.349
# L2.Temp_Avg      0.0831      1.734      0.048      0.962      -3.316       3.482
# L3.Demand       -0.0018      0.718     -0.002      0.998      -1.409       1.406
# L3.Temp_Avg      0.0105      2.551      0.004      0.997      -4.989       5.010
# L4.Demand       -0.0199      0.455     -0.044      0.965      -0.912       0.873
# L4.Temp_Avg     -0.0134      1.969     -0.007      0.995      -3.873       3.846
# L5.Demand        0.0064      0.451      0.014      0.989      -0.878       0.891
# L5.Temp_Avg     -0.0332      2.256     -0.015      0.988      -4.454       4.388
# L6.Demand        0.0255      0.467      0.055      0.956      -0.890       0.941
# L6.Temp_Avg     -0.0424      1.773     -0.024      0.981      -3.517       3.432
# L7.Demand        0.0120      0.606      0.020      0.984      -1.176       1.200
# L7.Temp_Avg     -0.0374      1.883     -0.020      0.984      -3.727       3.652
# L8.Demand        0.0202      0.796      0.025      0.980      -1.539       1.579
# L8.Temp_Avg     -0.0630      1.905     -0.033      0.974      -3.796       3.670
# L9.Demand        0.0174      0.657      0.026      0.979      -1.270       1.305
# L9.Temp_Avg     -0.1102      2.254     -0.049      0.961      -4.529       4.308
# L10.Demand       0.0085      0.654      0.013      0.990      -1.274       1.291
# L10.Temp_Avg    -0.0465      1.470     -0.032      0.975      -2.927       2.834
# L11.Demand      -0.0004      1.227     -0.000      1.000      -2.405       2.404
# L11.Temp_Avg     0.0968      3.082      0.031      0.975      -5.943       6.137
# L12.Demand       0.0032      1.677      0.002      0.998      -3.284       3.291
# L12.Temp_Avg     0.2072      3.159      0.066      0.948      -5.985       6.400
# L13.Demand       0.0085      0.793      0.011      0.991      -1.546       1.563
# L13.Temp_Avg     0.0583      1.757      0.033      0.974      -3.386       3.503
# L14.Demand       0.0058      0.505      0.012      0.991      -0.984       0.995
# L14.Temp_Avg    -0.0804      1.333     -0.060      0.952      -2.692       2.532
# L15.Demand       0.0141      0.815      0.017      0.986      -1.584       1.612
# L15.Temp_Avg    -0.1317      2.967     -0.044      0.965      -5.948       5.684
# L16.Demand       0.0053      0.843      0.006      0.995      -1.648       1.658
# L16.Temp_Avg    -0.0900      2.335     -0.039      0.969      -4.666       4.486
#                                   Error covariance matrix
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# sqrt.var.Demand              1.8574      2.368      0.784      0.433      -2.784       6.499
# sqrt.cov.Demand.Temp_Avg     0.0335      1.188      0.028      0.977      -2.296       2.363
# sqrt.var.Temp_Avg            0.5536      0.686      0.807      0.420      -0.791       1.898
# ============================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
n_forecast = 12
predict = fitted_model.get_prediction(start=len(df_train),end=len(df_train) + n_forecast-1)
predictions=predict.predicted_mean

# %%
predictions.columns=['Demand_predicted','Temp_Avg_predicted']
predictions
# Out:
#             Demand_predicted  Temp_Avg_predicted
# 2021-01-01         16.977163           25.185177
# 2021-02-01         17.223228           25.660864
# 2021-03-01         17.408903           26.238362
# 2021-04-01         18.313013           26.370148
# 2021-05-01         18.739593           26.087421
# 2021-06-01         18.346759           25.573779
# 2021-07-01         17.697881           25.149683
# 2021-08-01         18.167486           25.124272
# 2021-09-01         18.344695           25.164434
# 2021-10-01         17.787491           25.326721
# 2021-11-01         17.600110           25.401075
# 2021-12-01         17.648175           25.272882

# %%
test_vs_pred=pd.concat([df_test,predictions],axis=1)
test_vs_pred
# Out:
#                Demand  Temp_Avg  Demand_predicted  Temp_Avg_predicted
# 2021-01-01  17.997932      24.5         16.977163           25.185177
# 2021-02-01  18.036225      25.0         17.223228           25.660864
# 2021-03-01  19.635438      26.0         17.408903           26.238362
# 2021-04-01  18.983465      26.3         18.313013           26.370148
# 2021-05-01  18.365785      26.1         18.739593           26.087421
# 2021-06-01  18.186794      25.5         18.346759           25.573779
# 2021-07-01  18.492716      25.7         17.697881           25.149683
# 2021-08-01  19.855330      25.2         18.167486           25.124272
# 2021-09-01  18.928359      25.3         18.344695           25.164434
# 2021-10-01  19.511670      25.4         17.787491           25.326721
# 2021-11-01  20.258340      24.8         17.600110           25.401075
# 2021-12-01  19.257245      25.1         17.648175           25.272882

# %%
test_vs_pred.plot(figsize=(12,5))
# Out:
# <AxesSubplot:>

# %%
Mean_Square_Error=mean_squared_error(df_test,predictions,multioutput='raw_values')
print(Mean_Square_Error)
# Out:
# [1.97704591 0.14142157]

# %%
Root_Mean_Square_Error=sqrt(mean_squared_error(df_test,predictions))
print(Root_Mean_Square_Error)
# Out:
# 1.0291908170929718

# %%
Mean_Absolute_Error=mean_absolute_error(df_test,predictions)
print(Mean_Absolute_Error)
# Out:
# 0.7363376969705447
